# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import numpy as np

# %%
CLIENT_ID = "6fadbdba066e47b8a5eb752de49bb202"
CLIENT_SECRET = "d5fe58aff0094c7586d8542f2fe1f3ac"
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
my_playlists = sp.user_playlists('tz0j2laeudcuwymfeh15xovgt')

# %%
selected_playlists = {}


for playlist in my_playlists['items']:
    if not playlist['collaborative']:
        print(playlist['id'], playlist['name'], playlist['tracks']['total'])
        selected_playlists[playlist['id']] = {
            'name': playlist['name'],
            'number_of_songs': playlist['tracks']['total']
        }

#Eliminating the playlists that I don't need for analysis
eliminate = ['58OroFc8yqiLswqnPHqllM', '2fVTUS27Es6mym3ScOaNUT', '3u2649hgxZu7s6GFeEuSho', 
            '2jOKBcK1uDJiafpTRqKPrX', '5kB3ILLfhrWJl8bIIka7Kg', '10F2GFf0WSnRSyeD4qAL3L',
            '126EqL0ywBsB0ObBXAKY4G', '1Bqstr4Q2xibU6mOnpmxKa']

for playlist in eliminate:
    del selected_playlists[playlist]

selected_playlists
# Out:
# 2fVTUS27Es6mym3ScOaNUT Mellow Indie Vibes: Parcels, Cigarettes After Sex, Japanese Breakfast, Men I Trust, Arctic Monkeys 60
# 58OroFc8yqiLswqnPHqllM Rap 🎤 6
# 3u2649hgxZu7s6GFeEuSho Too upbeat for my sad personality ✨ 9
# 2jOKBcK1uDJiafpTRqKPrX Sad but fuck it  3
# 1Bqstr4Q2xibU6mOnpmxKa Chasing dreams ✨ 16
# 6jbn1cwPrem1cT1guLU5Zl hodgepodge. 1086
# 1CWo5l9p4gcqQhruiGdAob Onism ✨ 247
# 3ddZK1m1mr6FtP5BmyolU7 main character vibes 👠 58
# 1QpqySIlaPmjgWPK7PX0xU All Tears 😭  27
# 18AIhbwCnKN10i2b3WVcRy Groove👟 29
# 4GJQP0QvNiBd7dy9BzAVcM South side 🍛 28
# 5VY5MFMlSL9JzkSm7Si8Ng Bollywood / North Side 👳🏻‍♂️ 191
# 1wTLCLKxifLfvDCgt6INJf Anachronistic / Bangers 📜 73
# 5kB3ILLfhrWJl8bIIka7Kg World tour 🌍 13
# 6E6I8G7R4eqTlrVlGsgSnr Sound of music 🎼  24
# 10F2GFf0WSnRSyeD4qAL3L weird discoveries. 8
# 126EqL0ywBsB0ObBXAKY4G Coolies Mixtape 📼 90
# {'6jbn1cwPrem1cT1guLU5Zl': {'name': 'hodgepodge.', 'number_of_songs': 1086},
#  '1CWo5l9p4gcqQhruiGdAob': {'name': 'Onism ✨', 'number_of_songs': 247},
#  '3ddZK1m1mr6FtP5BmyolU7': {'name': 'main character vibes 👠',
#   'number_of_songs': 58},
#  '1QpqySIlaPmjgWPK7PX0xU': {'name': 'All Tears 😭 ', 'number_of_songs': 27},
#  '18AIhbwCnKN10i2b3WVcRy': {'name': 'Groove👟', 'number_of_songs': 29},
#  '4GJQP0QvNiBd7dy9BzAVcM': {'name': 'South side 🍛', 'number_of_songs': 28},
#  '5VY5MFMlSL9JzkSm7Si8Ng': {'name': 'Bollywood / North Side 👳🏻\u200d♂️',
#   'number_of_songs': 191},
#  '1wTLCLKxifLfvDCgt6INJf': {'name': 'Anachronistic / Bangers 📜',
#   'number_of_songs': 73},
#  '6E6I8G7R4eqTlrVlGsgSnr': {'name': 'Sound of music 🎼 ',
#   'number_of_songs': 24}}

# %%
columns = ['track_id', 'track_name', 'artists', 'album', 'danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'key', 'mode', 'playlist']
All_playlists = pd.DataFrame(columns=columns)
All_playlists
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, artists, album, danceability, energy, speechiness, acousticness, instrumentalness, liveness, valence, tempo, key, mode, playlist]
# Index: []

# %%
for playlist_id in selected_playlists:
    print("Collecting the songs in playlist", selected_playlists[playlist_id]['name'])

    for off in range(0,selected_playlists[playlist_id]['number_of_songs'], 100):
        tracks = sp.playlist_items(playlist_id = playlist_id,limit=100, offset=off)["items"]
        
        for track in tracks:

            artists = ""
            for artist in track['track']['artists']:
                artists += artist['name'] + ", "
                
            song_row = {
                'track_id': track['track']['id'],
                'track_name': track['track']['name'],
                'artists': artists,
                'album': track['track']['album']['name']
            }

            for col in columns[4:-1]:
                song_row[col] = np.nan

            song_row['playlist'] = selected_playlists[playlist_id]['name']

            All_playlists.loc[len(All_playlists.index)] = song_row.values()


            print("==================================================", off, "/", selected_playlists[playlist_id]['number_of_songs'])
    
All_playlists
# Out:
# Collecting the songs in playlist hodgepodge.
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 0 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 100 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 200 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 300 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 400 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 500 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 600 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ================================================== 700 / 1086
# ...
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 0 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# ================================================== 100 / 191
# Collecting the songs in playlist Anachronistic / Bangers 📜
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# ================================================== 0 / 73
# Collecting the songs in playlist Sound of music 🎼
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
# ================================================== 0 / 24
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")           NaN     NaN
# 1                                   A Place We Knew           NaN     NaN
# 2                                       Handwritten           NaN     NaN
# 3                                         Rescue Me           NaN     NaN
# 4                       Poems, Prayers and Promises           NaN     NaN
# ...                                             ...           ...     ...
# 1758                                    The Village           NaN     NaN
# 1759                                   Undiscovered           NaN     NaN
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)           NaN     NaN
# 1762                      Small Craft On A Milk Sea           NaN     NaN
#
#       speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0             NaN           NaN               NaN       NaN      NaN    NaN
# 1             NaN           NaN               NaN       NaN      NaN    NaN
# 2             NaN           NaN               NaN       NaN      NaN    NaN
# 3             NaN           NaN               NaN       NaN      NaN    NaN
# 4             NaN           NaN               NaN       NaN      NaN    NaN
# ...           ...           ...               ...       ...      ...    ...
# 1758          NaN           NaN               NaN       NaN      NaN    NaN
# 1759          NaN           NaN               NaN       NaN      NaN    NaN
# 1760          NaN           NaN               NaN       NaN      NaN    NaN
# 1761          NaN           NaN               NaN       NaN      NaN    NaN
# 1762          NaN           NaN               NaN       NaN      NaN    NaN
#
#       key  mode           playlist
# 0     NaN   NaN        hodgepodge.
# 1     NaN   NaN        hodgepodge.
# 2     NaN   NaN        hodgepodge.
# 3     NaN   NaN        hodgepodge.
# 4     NaN   NaN        hodgepodge.
# ...   ...   ...                ...
# 1758  NaN   NaN  Sound of music 🎼
# 1759  NaN   NaN  Sound of music 🎼
# 1760  NaN   NaN  Sound of music 🎼
# 1761  NaN   NaN  Sound of music 🎼
# 1762  NaN   NaN  Sound of music 🎼
#
# [1763 rows x 15 columns]

# %%
All_playlists
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")           NaN     NaN
# 1                                   A Place We Knew           NaN     NaN
# 2                                       Handwritten           NaN     NaN
# 3                                         Rescue Me           NaN     NaN
# 4                       Poems, Prayers and Promises           NaN     NaN
# ...                                             ...           ...     ...
# 1758                                    The Village           NaN     NaN
# 1759                                   Undiscovered           NaN     NaN
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)           NaN     NaN
# 1762                      Small Craft On A Milk Sea           NaN     NaN
#
#       speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0             NaN           NaN               NaN       NaN      NaN    NaN
# 1             NaN           NaN               NaN       NaN      NaN    NaN
# 2             NaN           NaN               NaN       NaN      NaN    NaN
# 3             NaN           NaN               NaN       NaN      NaN    NaN
# 4             NaN           NaN               NaN       NaN      NaN    NaN
# ...           ...           ...               ...       ...      ...    ...
# 1758          NaN           NaN               NaN       NaN      NaN    NaN
# 1759          NaN           NaN               NaN       NaN      NaN    NaN
# 1760          NaN           NaN               NaN       NaN      NaN    NaN
# 1761          NaN           NaN               NaN       NaN      NaN    NaN
# 1762          NaN           NaN               NaN       NaN      NaN    NaN
#
#       key  mode           playlist
# 0     NaN   NaN        hodgepodge.
# 1     NaN   NaN        hodgepodge.
# 2     NaN   NaN        hodgepodge.
# 3     NaN   NaN        hodgepodge.
# 4     NaN   NaN        hodgepodge.
# ...   ...   ...                ...
# 1758  NaN   NaN  Sound of music 🎼
# 1759  NaN   NaN  Sound of music 🎼
# 1760  NaN   NaN  Sound of music 🎼
# 1761  NaN   NaN  Sound of music 🎼
# 1762  NaN   NaN  Sound of music 🎼
#
# [1763 rows x 15 columns]

# %%
error_track_ids = []

for off in range(0, len(All_playlists.index), 100):
    track_ids = All_playlists['track_id'].iloc[off:100+off].tolist()

    # Remove any empty or invalid track IDs
    track_ids = [tid for tid in track_ids if isinstance(tid, str) and len(tid) == 22]

    try:
        # Filter out None values
        track_ids = [tid for tid in track_ids if tid is not None]

        if track_ids:
            song_features = sp.audio_features(tracks=track_ids)
            
            for feature in song_features:
                track_id = feature['id']
                row_index = All_playlists.index[All_playlists['track_id'] == track_id].tolist()

                if row_index:
                    row = row_index[0]

                    # Update columns 4:-1 with audio features
                    for ele in All_playlists.columns[4:-1]:
                        All_playlists.loc[row, ele] = feature[ele]
    except Exception as e:
        print(f"Error processing track IDs: {e}")
        # Store the failed track IDs
        error_track_ids.extend(track_ids)

# Display the updated DataFrame
print(All_playlists)

# Display the track IDs that encountered errors
print("Track IDs with errors:", error_track_ids)
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")         0.584  0.4070
# 1                                   A Place We Knew         0.613  0.7390
# 2                                       Handwritten         0.451  0.5070
# 3                                         Rescue Me         0.759  0.6050
# 4                       Poems, Prayers and Promises         0.462  0.3950
# ...                                             ...           ...     ...
# 1758                                    The Village         0.140  0.1160
# 1759                                   Undiscovered         0.464  0.4930
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)         0.298  0.1480
# 1762                      Small Craft On A Milk Sea         0.222  0.0405
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0460         0.476             0.000    0.1800   0.3410  115.124
# 1          0.0311         0.526             0.000    0.1490   0.7120  104.966
# 2          0.0316         0.473             0.000    0.1080   0.5640  165.760
# 3          0.0433         0.156             0.000    0.6940   0.6400  121.049
# 4          0.0264         0.758             0.000    0.1210   0.6250   82.259
# ...           ...           ...               ...       ...      ...      ...
# 1758       0.0378         0.813             0.163    0.2100   0.1040   86.097
# 1759       0.0380         0.793             0.757    0.0986   0.0391   90.534
# 1760          NaN           NaN               NaN       NaN      NaN      NaN
# 1761       0.0438         0.868             0.843    0.1100   0.0603  108.658
# 1762       0.0647         0.986             0.932    0.0766   0.0388  178.846
#
#        key  mode           playlist
# 0      1.0   0.0        hodgepodge.
# 1     10.0   1.0        hodgepodge.
# 2     11.0   1.0        hodgepodge.
# 3      7.0   1.0        hodgepodge.
# 4      9.0   1.0        hodgepodge.
# ...    ...   ...                ...
# 1758   7.0   0.0  Sound of music 🎼
# 1759   9.0   0.0  Sound of music 🎼
# 1760   NaN   NaN  Sound of music 🎼
# 1761   3.0   0.0  Sound of music 🎼
# 1762  11.0   1.0  Sound of music 🎼
#
# [1763 rows x 15 columns]
# Track IDs with errors: []

# %%
All_playlists
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")         0.584  0.4070
# 1                                   A Place We Knew         0.613  0.7390
# 2                                       Handwritten         0.451  0.5070
# 3                                         Rescue Me         0.759  0.6050
# 4                       Poems, Prayers and Promises         0.462  0.3950
# ...                                             ...           ...     ...
# 1758                                    The Village         0.140  0.1160
# 1759                                   Undiscovered         0.464  0.4930
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)         0.298  0.1480
# 1762                      Small Craft On A Milk Sea         0.222  0.0405
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0460         0.476             0.000    0.1800   0.3410  115.124
# 1          0.0311         0.526             0.000    0.1490   0.7120  104.966
# 2          0.0316         0.473             0.000    0.1080   0.5640  165.760
# 3          0.0433         0.156             0.000    0.6940   0.6400  121.049
# 4          0.0264         0.758             0.000    0.1210   0.6250   82.259
# ...           ...           ...               ...       ...      ...      ...
# 1758       0.0378         0.813             0.163    0.2100   0.1040   86.097
# 1759       0.0380         0.793             0.757    0.0986   0.0391   90.534
# 1760          NaN           NaN               NaN       NaN      NaN      NaN
# 1761       0.0438         0.868             0.843    0.1100   0.0603  108.658
# 1762       0.0647         0.986             0.932    0.0766   0.0388  178.846
#
#        key  mode           playlist
# 0      1.0   0.0        hodgepodge.
# 1     10.0   1.0        hodgepodge.
# 2     11.0   1.0        hodgepodge.
# 3      7.0   1.0        hodgepodge.
# 4      9.0   1.0        hodgepodge.
# ...    ...   ...                ...
# 1758   7.0   0.0  Sound of music 🎼
# 1759   9.0   0.0  Sound of music 🎼
# 1760   NaN   NaN  Sound of music 🎼
# 1761   3.0   0.0  Sound of music 🎼
# 1762  11.0   1.0  Sound of music 🎼
#
# [1763 rows x 15 columns]

# %%
All_playlists.to_csv('FinalPlaylist.csv', index=False)

# %%
error_track_ids = []
for off in range(0, len(All_playlists.index), 100):
    track_ids = All_playlists['track_id'].iloc[off:100+off].tolist()

    # Remove any empty or invalid track IDs
    track_ids = [tid for tid in track_ids if isinstance(tid, str) and len(tid) == 22]

    try:
        # Filter out None values
        track_ids = [tid for tid in track_ids if tid is not None]

        if track_ids:
            song_features = sp.audio_features(tracks=track_ids)
            
            for feature in song_features:
                track_id = feature['id']
                row_index = All_playlists.index[All_playlists['track_id'] == track_id].tolist()

                if row_index:
                    row = row_index[0]

                    # Update columns 4:-1 with audio features
                    for ele in All_playlists.columns[4:-1]:
                        All_playlists.loc[row, ele] = feature[ele]
    except Exception as e:
        print(f"Error processing track IDs: {e}")
        # Store the failed track IDs
        error_track_ids.extend(track_ids)

# Display the updated DataFrame
print(All_playlists)

# Display the track IDs that encountered errors
print("Track IDs with errors:", error_track_ids)
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")         0.584  0.4070
# 1                                   A Place We Knew         0.613  0.7390
# 2                                       Handwritten         0.451  0.5070
# 3                                         Rescue Me         0.759  0.6050
# 4                       Poems, Prayers and Promises         0.462  0.3950
# ...                                             ...           ...     ...
# 1758                                    The Village         0.140  0.1160
# 1759                                   Undiscovered         0.464  0.4930
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)         0.298  0.1480
# 1762                      Small Craft On A Milk Sea         0.222  0.0405
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0460         0.476             0.000    0.1800   0.3410  115.124
# 1          0.0311         0.526             0.000    0.1490   0.7120  104.966
# 2          0.0316         0.473             0.000    0.1080   0.5640  165.760
# 3          0.0433         0.156             0.000    0.6940   0.6400  121.049
# 4          0.0264         0.758             0.000    0.1210   0.6250   82.259
# ...           ...           ...               ...       ...      ...      ...
# 1758       0.0378         0.813             0.163    0.2100   0.1040   86.097
# 1759       0.0380         0.793             0.757    0.0986   0.0391   90.534
# 1760          NaN           NaN               NaN       NaN      NaN      NaN
# 1761       0.0438         0.868             0.843    0.1100   0.0603  108.658
# 1762       0.0647         0.986             0.932    0.0766   0.0388  178.846
#
#        key  mode           playlist
# 0      1.0   0.0        hodgepodge.
# 1     10.0   1.0        hodgepodge.
# 2     11.0   1.0        hodgepodge.
# 3      7.0   1.0        hodgepodge.
# 4      9.0   1.0        hodgepodge.
# ...    ...   ...                ...
# 1758   7.0   0.0  Sound of music 🎼
# 1759   9.0   0.0  Sound of music 🎼
# 1760   NaN   NaN  Sound of music 🎼
# 1761   3.0   0.0  Sound of music 🎼
# 1762  11.0   1.0  Sound of music 🎼
#
# [1763 rows x 15 columns]
# Track IDs with errors: []

# %%
All_playlists
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1760  3mZ33QYHWylbabTz82rHwj                                         So What
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1760                           Miles Davis,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                               album  danceability  energy  \
# 0              Fire On Fire (From "Watership Down")         0.584  0.4070
# 1                                   A Place We Knew         0.613  0.7390
# 2                                       Handwritten         0.451  0.5070
# 3                                         Rescue Me         0.759  0.6050
# 4                       Poems, Prayers and Promises         0.462  0.3950
# ...                                             ...           ...     ...
# 1758                                    The Village         0.140  0.1160
# 1759                                   Undiscovered         0.464  0.4930
# 1760   Pleasantville -Music From The Motion Picture           NaN     NaN
# 1761  Monsters (Original Motion Picture Soundtrack)         0.298  0.1480
# 1762                      Small Craft On A Milk Sea         0.222  0.0405
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0460         0.476             0.000    0.1800   0.3410  115.124
# 1          0.0311         0.526             0.000    0.1490   0.7120  104.966
# 2          0.0316         0.473             0.000    0.1080   0.5640  165.760
# 3          0.0433         0.156             0.000    0.6940   0.6400  121.049
# 4          0.0264         0.758             0.000    0.1210   0.6250   82.259
# ...           ...           ...               ...       ...      ...      ...
# 1758       0.0378         0.813             0.163    0.2100   0.1040   86.097
# 1759       0.0380         0.793             0.757    0.0986   0.0391   90.534
# 1760          NaN           NaN               NaN       NaN      NaN      NaN
# 1761       0.0438         0.868             0.843    0.1100   0.0603  108.658
# 1762       0.0647         0.986             0.932    0.0766   0.0388  178.846
#
#        key  mode           playlist
# 0      1.0   0.0        hodgepodge.
# 1     10.0   1.0        hodgepodge.
# 2     11.0   1.0        hodgepodge.
# 3      7.0   1.0        hodgepodge.
# 4      9.0   1.0        hodgepodge.
# ...    ...   ...                ...
# 1758   7.0   0.0  Sound of music 🎼
# 1759   9.0   0.0  Sound of music 🎼
# 1760   NaN   NaN  Sound of music 🎼
# 1761   3.0   0.0  Sound of music 🎼
# 1762  11.0   1.0  Sound of music 🎼
#
# [1763 rows x 15 columns]

# %%
df = All_playlists.dropna().drop_duplicates()

# %%
df
# Out:
#                     track_id                                      track_name  \
# 0     5rFj8OzffT0iggSjcBaeND            Fire On Fire - From "Watership Down"
# 1     6FYbr9QzRoZPh0Re8lDO9z                                       7 Minutes
# 2     1T7AiFL9ruKKwlONN35Vh0                               A Little Too Much
# 3     0mjAU3yKR1QnXnHtjGJqTM                                       Rescue Me
# 4     1YYhDizHx7PnDhAhko6cDS  Take Me Home, Country Roads - Original Version
# ...                      ...                                             ...
# 1757  2Zb6Cu5peVtG3UDifxEd1u                                    The Avengers
# 1758  5ynPIIbdGo2OBoX9vcnUo5                         The Gravel Road - Score
# 1759  2WGmCL4wPC9RoGvRnp8Goz                        Choros - Remastered 2020
# 1761  7aS8e5XKVWDcbyn06mF9fz                                         Candles
# 1762  6fymXW3eFHPmIOdDfnLXS4                               Emerald and Stone
#
#                                      artists  \
# 0                                Sam Smith,
# 1                               Dean Lewis,
# 2                             Shawn Mendes,
# 3                              OneRepublic,
# 4                              John Denver,
# ...                                      ...
# 1757                        Alan Silvestri,
# 1758                   James Newton Howard,
# 1759                      Ludovico Einaudi,
# 1761                           Jon Hopkins,
# 1762  Brian Eno, Jon Hopkins, Leo Abrahams,
#
#                                                   album  danceability  energy  \
# 0                  Fire On Fire (From "Watership Down")         0.584  0.4070
# 1                                       A Place We Knew         0.613  0.7390
# 2                                           Handwritten         0.451  0.5070
# 3                                             Rescue Me         0.759  0.6050
# 4                           Poems, Prayers and Promises         0.462  0.3950
# ...                                                 ...           ...     ...
# 1757  Avengers: Infinity War (Original Motion Pictur...         0.365  0.2750
# 1758                                        The Village         0.140  0.1160
# 1759                                       Undiscovered         0.464  0.4930
# 1761      Monsters (Original Motion Picture Soundtrack)         0.298  0.1480
# 1762                          Small Craft On A Milk Sea         0.222  0.0405
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0460         0.476             0.000    0.1800   0.3410  115.124
# 1          0.0311         0.526             0.000    0.1490   0.7120  104.966
# 2          0.0316         0.473             0.000    0.1080   0.5640  165.760
# 3          0.0433         0.156             0.000    0.6940   0.6400  121.049
# 4          0.0264         0.758             0.000    0.1210   0.6250   82.259
# ...           ...           ...               ...       ...      ...      ...
# 1757       0.0738         0.196             0.960    0.0650   0.0846   84.388
# 1758       0.0378         0.813             0.163    0.2100   0.1040   86.097
# 1759       0.0380         0.793             0.757    0.0986   0.0391   90.534
# 1761       0.0438         0.868             0.843    0.1100   0.0603  108.658
# 1762       0.0647         0.986             0.932    0.0766   0.0388  178.846
#
#        key  mode           playlist
# 0      1.0   0.0        hodgepodge.
# 1     10.0   1.0        hodgepodge.
# 2     11.0   1.0        hodgepodge.
# 3      7.0   1.0        hodgepodge.
# 4      9.0   1.0        hodgepodge.
# ...    ...   ...                ...
# 1757   9.0   1.0  Sound of music 🎼
# 1758   7.0   0.0  Sound of music 🎼
# 1759   9.0   0.0  Sound of music 🎼
# 1761   3.0   0.0  Sound of music 🎼
# 1762  11.0   1.0  Sound of music 🎼
#
# [1450 rows x 15 columns]

# %%
playlist = {}
for value in df['playlist'].unique():
    playlist[value] = df[df['playlist'] == value]
    columns_to_drop = ['track_id', 'track_name', 'artists', 'album', 'playlist']
    playlist[value] = playlist[value].drop(columns=columns_to_drop)

# %%
combined_df = pd.concat(playlist.values(), ignore_index=True)
combined_df.corr()
# Out:
#                   danceability    energy  speechiness  acousticness  \
# danceability          1.000000  0.241110     0.254092     -0.252443
# energy                0.241110  1.000000     0.146435     -0.753185
# speechiness           0.254092  0.146435     1.000000     -0.136480
# acousticness         -0.252443 -0.753185    -0.136480      1.000000
# instrumentalness     -0.105724  0.005687    -0.076361      0.029504
# liveness              0.039981  0.180324     0.083156     -0.118887
# valence               0.474347  0.429396     0.159538     -0.288345
# tempo                -0.101641  0.153249     0.003165     -0.147977
# key                  -0.003134  0.031081     0.013689     -0.005882
# mode                 -0.135103 -0.134852    -0.124381      0.138044
#
#                   instrumentalness  liveness   valence     tempo       key  \
# danceability             -0.105724  0.039981  0.474347 -0.101641 -0.003134
# energy                    0.005687  0.180324  0.429396  0.153249  0.031081
# speechiness              -0.076361  0.083156  0.159538  0.003165  0.013689
# acousticness              0.029504 -0.118887 -0.288345 -0.147977 -0.005882
# instrumentalness          1.000000  0.012483 -0.176439  0.024879  0.060356
# liveness                  0.012483  1.000000  0.089584  0.020900  0.018001
# valence                  -0.176439  0.089584  1.000000  0.031161  0.022970
# tempo                     0.024879  0.020900  0.031161  1.000000  0.030960
# key                       0.060356  0.018001  0.022970  0.030960  1.000000
# mode                     -0.018045 -0.057836 -0.066115 -0.007934 -0.109685
#
#                       mode
# danceability     -0.135103
# energy           -0.134852
# speechiness      -0.124381
# acousticness      0.138044
# instrumentalness -0.018045
# liveness         -0.057836
# valence          -0.066115
# tempo            -0.007934
# key              -0.109685
# mode              1.000000

# %%
# !pip i
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 combined_df.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'hodgepodge.'

# %%
average_values = combined_df.groupby('playlist').mean()
average_values

# %%
average_values.to_csv("average_music.csv")

# %%
All_pla
